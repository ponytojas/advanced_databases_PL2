# %%
import pandas as pd
import random as rd

# %%
counter = 1
item_name =[]

for index in range(0, 1000000):
    item_name.append('item_' + str(counter))
    counter += 1

# %%
counter = 1
item_type = []

for index in range(0, 300):
    item_type.append('type_' + str(counter))
    counter += 1

# %%
dict_items = []
barcode_counter = 0

for item in item_name:
    barcode_counter += 1
    barcode = str(barcode_counter).zfill(7)  
    type_item = rd.choice(item_type)
    price = rd.randint(50, 1000)
    description = "Nombre: " + str(item) + "   Tipo: " + str(type_item) +"   Precio: " + str(price)
    
    item = {'Codigo de barras': barcode, 'Nombre': item, 'Tipo': type_item, 'Descripcion': description, 'Precio': price}
    dict_items.append(item)

# %%
dict_items
# Out:
# [{'Codigo de barras': '0000001',
#   'Nombre': 'item_1',
#   'Tipo': 'type_13',
#   'Descripcion': 'Nombre: item_1   Tipo: type_13   Precio: 799',
#   'Precio': 799},
#  {'Codigo de barras': '0000002',
#   'Nombre': 'item_2',
#   'Tipo': 'type_53',
#   'Descripcion': 'Nombre: item_2   Tipo: type_53   Precio: 926',
#   'Precio': 926},
#  {'Codigo de barras': '0000003',
#   'Nombre': 'item_3',
#   'Tipo': 'type_179',
#   'Descripcion': 'Nombre: item_3   Tipo: type_179   Precio: 357',
#   'Precio': 357},
#  {'Codigo de barras': '0000004',
#   'Nombre': 'item_4',
#   'Tipo': 'type_97',
#   'Descripcion': 'Nombre: item_4   Tipo: type_97   Precio: 78',
#   'Precio': 78},
#  {'Codigo de barras': '0000005',
#   'Nombre': 'item_5',
#   'Tipo': 'type_215',
#   'Descripcion': 'Nombre: item_5   Tipo: type_215   Precio: 466',
#   'Precio': 466},
#  {'Codigo de barras': '0000006',
#   'Nombre': 'item_6',
#   'Tipo': 'type_70',
#   'Descripcion': 'Nombre: item_6   Tipo: type_70   Precio: 381',
#   'Precio': 381},
#  {'Codigo de barras': '0000007',
#   'Nombre': 'item_7',
#   'Tipo': 'type_95',
#   'Descripcion': 'Nombre: item_7   Tipo: type_95   Precio: 149',
#   'Precio': 149},
#  {'Codigo de barras': '0000008',
#   'Nombre': 'item_8',
#   'Tipo': 'type_208',
#   'Descripcion': 'Nombre: item_8   Tipo: type_208   Precio: 265',
#   'Precio': 265},
#  {'Codigo de barras': '0000009',
#   'Nombre': 'item_9',
#   'Tipo': 'type_25',
#   'Descripcion': 'Nombre: item_9   Tipo: type_25   Precio: 588',
#   'Precio': 588},
#  {'Codigo de barras': '0000010',
#   'Nombre': 'item_10',
#   'Tipo': 'type_163',
#   'Descripcion': 'Nombre: item_10   Tipo: type_163   Precio: 837',
#   'Precio': 837},
#  {'Codigo de barras': '0000011',
#   'Nombre': 'item_11',
#   'Tipo': 'type_195',
#   'Descripcion': 'Nombre: item_11   Tipo: type_195   Precio: 606',
#   'Precio': 606},
#  {'Codigo de barras': '0000012',
#   'Nombre': 'item_12',
#   'Tipo': 'type_27',
#   'Descripcion': 'Nombre: item_12   Tipo: type_27   Precio: 168',
#   'Precio': 168},
#  {'Codigo de barras': '0000013',
#   'Nombre': 'item_13',
#   'Tipo': 'type_13',
#   'Descripcion': 'Nombre: item_13   Tipo: type_13   Precio: 681',
#   'Precio': 681},
#  {'Codigo de barras': '0000014',
#   'Nombre': 'item_14',
#   'Tipo': 'type_272',
#   'Descripcion': 'Nombre: item_14   Tipo: type_272   Precio: 390',
#   'Precio': 390},
#  {'Codigo de barras': '0000015',
#   'Nombre': 'item_15',
#   'Tipo': 'type_84',
#   'Descripcion': 'Nombre: item_15   Tipo: type_84   Precio: 398',
#   'Precio': 398},
#  {'Codigo de barras': '0000016',
#   'Nombre': 'item_16',
#   'Tipo': 'type_47',
#   'Descripcion': 'Nombre: item_16   Tipo: type_47   Precio: 152',
#   'Precio': 152},
#  {'Codigo de barras': '0000017',
#   'Nombre': 'item_17',
#   'Tipo': 'type_267',
#   'Descripcion': 'Nombre: item_17   Tipo: type_267   Precio: 377',
#   'Precio': 377},
#  {'Codigo de barras': '0000018',
#   'Nombre': 'item_18',
#   'Tipo': 'type_22',
#   'Descripcion': 'Nombre: item_18   Tipo: type_22   Precio: 443',
#   'Precio': 443},
#  {'Codigo de barras': '0000019',
#   'Nombre': 'item_19',
#   'Tipo': 'type_139',
#   'Descripcion': 'Nombre: item_19   Tipo: type_139   Precio: 420',
#   'Precio': 420},
#  {'Codigo de barras': '0000020',
#   'Nombre': 'item_20',
#   'Tipo': 'type_274',
#   'Descripcion': 'Nombre: item_20   Tipo: type_274   Precio: 510',
#   'Precio': 510},
#  {'Codigo de barras': '0000021',
#   'Nombre': 'item_21',
#   'Tipo': 'type_32',
#   'Descripcion': 'Nombre: item_21   Tipo: type_32   Precio: 812',
#   'Precio': 812},
#  {'Codigo de barras': '0000022',
#   'Nombre': 'item_22',
#   'Tipo': 'type_72',
#   'Descripcion': 'Nombre: item_22   Tipo: type_72   Precio: 66',
#   'Precio': 66},
#  {'Codigo de barras': '0000023',
#   'Nombre': 'item_23',
#   'Tipo': 'type_70',
#   'Descripcion': 'Nombre: item_23   Tipo: type_70   Precio: 800',
#   'Precio': 800},
#  {'Codigo de barras': '0000024',
#   'Nombre': 'item_24',
#   'Tipo': 'type_243',
#   'Descripcion': 'Nombre: item_24   Tipo: type_243   Precio: 632',
#   'Precio': 632},
#  {'Codigo de barras': '0000025',
#   'Nombre': 'item_25',
#   'Tipo': 'type_138',
#   'Descripcion': 'Nombre: item_25   Tipo: type_138   Precio: 967',
#   'Precio': 967},
#  {'Codigo de barras': '0000026',
#   'Nombre': 'item_26',
#   'Tipo': 'type_227',
#   'Descripcion': 'Nombre: item_26   Tipo: type_227   Precio: 879',
#   'Precio': 879},
#  {'Codigo de barras': '0000027',
#   'Nombre': 'item_27',
#   'Tipo': 'type_219',
#   'Descripcion': 'Nombre: item_27   Tipo: type_219   Precio: 95',
#   'Precio': 95},
#  {'Codigo de barras': '0000028',
#   'Nombre': 'item_28',
#   'Tipo': 'type_191',
#   'Descripcion': 'Nombre: item_28   Tipo: type_191   Precio: 450',
#   'Precio': 450},
#  {'Codigo de barras': '0000029',
#   'Nombre': 'item_29',
#   'Tipo': 'type_148',
#   'Descripcion': 'Nombre: item_29   Tipo: type_148   Precio: 536',
#   'Precio': 536},
#  {'Codigo de barras': '0000030',
#   'Nombre': 'item_30',
#   'Tipo': 'type_154',
#   'Descripcion': 'Nombre: item_30   Tipo: type_154   Precio: 111',
#   'Precio': 111},
#  {'Codigo de barras': '0000031',
#   'Nombre': 'item_31',
#   'Tipo': 'type_241',
#   'Descripcion': 'Nombre: item_31   Tipo: type_241   Precio: 57',
#   'Precio': 57},
#  {'Codigo de barras': '0000032',
#   'Nombre': 'item_32',
#   'Tipo': 'type_20',
#   'Descripcion': 'Nombre: item_32   Tipo: type_20   Precio: 330',
#   'Precio': 330},
#  {'Codigo de barras': '0000033',
#   'Nombre': 'item_33',
#   'Tipo': 'type_88',
#   'Descripcion': 'Nombre: item_33   Tipo: type_88   Precio: 464',
#   'Precio': 464},
#  {'Codigo de barras': '0000034',
#   'Nombre': 'item_34',
#   'Tipo': 'type_79',
#   'Descripcion': 'Nombre: item_34   Tipo: type_79   Precio: 421',
#   'Precio': 421},
#  {'Codigo de barras': '0000035',
#   'Nombre': 'item_35',
#   'Tipo': 'type_257',
#   'Descripcion': 'Nombre: item_35   Tipo: type_257   Precio: 299',
#   'Precio': 299},
#  {'Codigo de barras': '0000036',
#   'Nombre': 'item_36',
#   'Tipo': 'type_172',
#   'Descripcion': 'Nombre: item_36   Tipo: type_172   Precio: 453',
#   'Precio': 453},
#  {'Codigo de barras': '0000037',
#   'Nombre': 'item_37',
#   'Tipo': 'type_292',
#   'Descripcion': 'Nombre: item_37   Tipo: type_292   Precio: 504',
#   'Precio': 504},
#  {'Codigo de barras': '0000038',
#   'Nombre': 'item_38',
#   'Tipo': 'type_261',
#   'Descripcion': 'Nombre: item_38   Tipo: type_261   Precio: 763',
#   'Precio': 763},
#  {'Codigo de barras': '0000039',
#   'Nombre': 'item_39',
#   'Tipo': 'type_27',
#   'Descripcion': 'Nombre: item_39   Tipo: type_27   Precio: 673',
#   'Precio': 673},
#  {'Codigo de barras': '0000040',
#   'Nombre': 'item_40',
#   'Tipo': 'type_68',
#   'Descripcion': 'Nombre: item_40   Tipo: type_68   Precio: 450',
#   'Precio': 450},
#  {'Codigo de barras': '0000041',
#   'Nombre': 'item_41',
#   'Tipo': 'type_194',
#   'Descripcion': 'Nombre: item_41   Tipo: type_194   Precio: 411',
#   'Precio': 411},
#  {'Codigo de barras': '0000042',
#   'Nombre': 'item_42',
#   'Tipo': 'type_194',
#   'Descripcion': 'Nombre: item_42   Tipo: type_194   Precio: 926',
#   'Precio': 926},
#  {'Codigo de barras': '0000043',
#   'Nombre': 'item_43',
#   'Tipo': 'type_211',
#   'Descripcion': 'Nombre: item_43   Tipo: type_211   Precio: 835',
#   'Precio': 835},
#  {'Codigo de barras': '0000044',
#   'Nombre': 'item_44',
#   'Tipo': 'type_14',
#   'Descripcion': 'Nombre: item_44   Tipo: type_14   Precio: 67',
#   'Precio': 67},
#  {'Codigo de barras': '0000045',
#   'Nombre': 'item_45',
#   'Tipo': 'type_261',
#   'Descripcion': 'Nombre: item_45   Tipo: type_261   Precio: 677',
#   'Precio': 677},
#  {'Codigo de barras': '0000046',
#   'Nombre': 'item_46',
#   'Tipo': 'type_222',
#   'Descripcion': 'Nombre: item_46   Tipo: type_222   Precio: 665',
#   'Precio': 665},
#  {'Codigo de barras': '0000047',
#   'Nombre': 'item_47',
#   'Tipo': 'type_257',
#   'Descripcion': 'Nombre: item_47   Tipo: type_257   Precio: 474',
#   'Precio': 474},
#  {'Codigo de barras': '0000048',
#   'Nombre': 'item_48',
#   'Tipo': 'type_133',
#   'Descripcion': 'Nombre: item_48   Tipo: type_133   Precio: 360',
#   'Precio': 360},
#  {'Codigo de barras': '0000049',
#   'Nombre': 'item_49',
#   'Tipo': 'type_174',
#   'Descripcion': 'Nombre: item_49   Tipo: type_174   Precio: 773',
#   'Precio': 773},
#  {'Codigo de barras': '0000050',
#   'Nombre': 'item_50',
#   'Tipo': 'type_218',
#   'Descripcion': 'Nombre: item_50   Tipo: type_218   Precio: 962',
#   'Precio': 962},
#  {'Codigo de barras': '0000051',
#   'Nombre': 'item_51',
#   'Tipo': 'type_143',
#   'Descripcion': 'Nombre: item_51   Tipo: type_143   Precio: 260',
#   'Precio': 260},
#  {'Codigo de barras': '0000052',
#   'Nombre': 'item_52',
#   'Tipo': 'type_31',
#   'Descripcion': 'Nombre: item_52   Tipo: type_31   Precio: 227',
#   'Precio': 227},
#  {'Codigo de barras': '0000053',
#   'Nombre': 'item_53',
#   'Tipo': 'type_79',
#   'Descripcion': 'Nombre: item_53   Tipo: type_79   Precio: 184',
#   'Precio': 184},
#  {'Codigo de barras': '0000054',
#   'Nombre': 'item_54',
#   'Tipo': 'type_230',
#   'Descripcion': 'Nombre: item_54   Tipo: type_230   Precio: 810',
#   'Precio': 810},
#  {'Codigo de barras': '0000055',
#   'Nombre': 'item_55',
#   'Tipo': 'type_186',
#   'Descripcion': 'Nombre: item_55   Tipo: type_186   Precio: 163',
#   'Precio': 163},
#  {'Codigo de barras': '0000056',
#   'Nombre': 'item_56',
#   'Tipo': 'type_136',
#   'Descripcion': 'Nombre: item_56   Tipo: type_136   Precio: 480',
#   'Precio': 480},
#  {'Codigo de barras': '0000057',
#   'Nombre': 'item_57',
#   'Tipo': 'type_148',
#   'Descripcion': 'Nombre: item_57   Tipo: type_148   Precio: 993',
#   'Precio': 993},
#  {'Codigo de barras': '0000058',
#   'Nombre': 'item_58',
#   'Tipo': 'type_156',
#   'Descripcion': 'Nombre: item_58   Tipo: type_156   Precio: 215',
#   'Precio': 215},
#  {'Codigo de barras': '0000059',
#   'Nombre': 'item_59',
#   'Tipo': 'type_178',
#   'Descripcion': 'Nombre: item_59   Tipo: type_178   Precio: 103',
#   'Precio': 103},
#  {'Codigo de barras': '0000060',
#   'Nombre': 'item_60',
#   'Tipo': 'type_234',
#   'Descripcion': 'Nombre: item_60   Tipo: type_234   Precio: 792',
#   'Precio': 792},
#  {'Codigo de barras': '0000061',
#   'Nombre': 'item_61',
#   'Tipo': 'type_83',
#   'Descripcion': 'Nombre: item_61   Tipo: type_83   Precio: 586',
#   'Precio': 586},
#  {'Codigo de barras': '0000062',
#   'Nombre': 'item_62',
#   'Tipo': 'type_203',
#   'Descripcion': 'Nombre: item_62   Tipo: type_203   Precio: 687',
#   'Precio': 687},
#  {'Codigo de barras': '0000063',
#   'Nombre': 'item_63',
#   'Tipo': 'type_63',
#   'Descripcion': 'Nombre: item_63   Tipo: type_63   Precio: 476',
#   'Precio': 476},
#  {'Codigo de barras': '0000064',
#   'Nombre': 'item_64',
#   'Tipo': 'type_227',
#   'Descripcion': 'Nombre: item_64   Tipo: type_227   Precio: 997',
#   'Precio': 997},
#  {'Codigo de barras': '0000065',
#   'Nombre': 'item_65',
#   'Tipo': 'type_148',
#   'Descripcion': 'Nombre: item_65   Tipo: type_148   Precio: 589',
#   'Precio': 589},
#  {'Codigo de barras': '0000066',
#   'Nombre': 'item_66',
#   'Tipo': 'type_4',
#   'Descripcion': 'Nombre: item_66   Tipo: type_4   Precio: 443',
#   'Precio': 443},
#  {'Codigo de barras': '0000067',
#   'Nombre': 'item_67',
#   'Tipo': 'type_254',
#   'Descripcion': 'Nombre: item_67   Tipo: type_254   Precio: 57',
#   'Precio': 57},
#  {'Codigo de barras': '0000068',
#   'Nombre': 'item_68',
#   'Tipo': 'type_161',
#   'Descripcion': 'Nombre: item_68   Tipo: type_161   Precio: 970',
#   'Precio': 970},
#  {'Codigo de barras': '0000069',
#   'Nombre': 'item_69',
#   'Tipo': 'type_200',
#   'Descripcion': 'Nombre: item_69   Tipo: type_200   Precio: 895',
#   'Precio': 895},
#  {'Codigo de barras': '0000070',
#   'Nombre': 'item_70',
#   'Tipo': 'type_146',
#   'Descripcion': 'Nombre: item_70   Tipo: type_146   Precio: 648',
#   'Precio': 648},
#  {'Codigo de barras': '0000071',
#   'Nombre': 'item_71',
#   'Tipo': 'type_215',
#   'Descripcion': 'Nombre: item_71   Tipo: type_215   Precio: 723',
#   'Precio': 723},
#  {'Codigo de barras': '0000072',
#   'Nombre': 'item_72',
#   'Tipo': 'type_232',
#   'Descripcion': 'Nombre: item_72   Tipo: type_232   Precio: 873',
#   'Precio': 873},
#  {'Codigo de barras': '0000073',
#   'Nombre': 'item_73',
#   'Tipo': 'type_21',
#   'Descripcion': 'Nombre: item_73   Tipo: type_21   Precio: 731',
#   'Precio': 731},
#  {'Codigo de barras': '0000074',
#   'Nombre': 'item_74',
#   'Tipo': 'type_32',
#   'Descripcion': 'Nombre: item_74   Tipo: type_32   Precio: 228',
#   'Precio': 228},
#  {'Codigo de barras': '0000075',
#   'Nombre': 'item_75',
#   'Tipo': 'type_225',
#   'Descripcion': 'Nombre: item_75   Tipo: type_225   Precio: 320',
#   'Precio': 320},
#  {'Codigo de barras': '0000076',
#   'Nombre': 'item_76',
#   'Tipo': 'type_14',
#   'Descripcion': 'Nombre: item_76   Tipo: type_14   Precio: 436',
#   'Precio': 436},
#  {'Codigo de barras': '0000077',
#   'Nombre': 'item_77',
#   'Tipo': 'type_50',
#   'Descripcion': 'Nombre: item_77   Tipo: type_50   Precio: 981',
#   'Precio': 981},
#  {'Codigo de barras': '0000078',
#   'Nombre': 'item_78',
#   'Tipo': 'type_107',
#   'Descripcion': 'Nombre: item_78   Tipo: type_107   Precio: 589',
#   'Precio': 589},
#  {'Codigo de barras': '0000079',
#   'Nombre': 'item_79',
#   'Tipo': 'type_238',
#   'Descripcion': 'Nombre: item_79   Tipo: type_238   Precio: 519',
#   'Precio': 519},
#  {'Codigo de barras': '0000080',
#   'Nombre': 'item_80',
#   'Tipo': 'type_215',
#   'Descripcion': 'Nombre: item_80   Tipo: type_215   Precio: 602',
#   'Precio': 602},
#  {'Codigo de barras': '0000081',
#   'Nombre': 'item_81',
#   'Tipo': 'type_2',
#   'Descripcion': 'Nombre: item_81   Tipo: type_2   Precio: 50',
#   'Precio': 50},
#  {'Codigo de barras': '0000082',
#   'Nombre': 'item_82',
#   'Tipo': 'type_107',
#   'Descripcion': 'Nombre: item_82   Tipo: type_107   Precio: 643',
#   'Precio': 643},
#  {'Codigo de barras': '0000083',
#   'Nombre': 'item_83',
#   'Tipo': 'type_128',
#   'Descripcion': 'Nombre: item_83   Tipo: type_128   Precio: 910',
#   'Precio': 910},
#  {'Codigo de barras': '0000084',
#   'Nombre': 'item_84',
#   'Tipo': 'type_107',
#   'Descripcion': 'Nombre: item_84   Tipo: type_107   Precio: 203',
#   'Precio': 203},
#  {'Codigo de barras': '0000085',
#   'Nombre': 'item_85',
#   'Tipo': 'type_79',
#   'Descripcion': 'Nombre: item_85   Tipo: type_79   Precio: 467',
#   'Precio': 467},
#  {'Codigo de barras': '0000086',
#   'Nombre': 'item_86',
#   'Tipo': 'type_41',
#   'Descripcion': 'Nombre: item_86   Tipo: type_41   Precio: 838',
#   'Precio': 838},
#  {'Codigo de barras': '0000087',
#   'Nombre': 'item_87',
#   'Tipo': 'type_213',
#   'Descripcion': 'Nombre: item_87   Tipo: type_213   Precio: 323',
#   'Precio': 323},
#  {'Codigo de barras': '0000088',
#   'Nombre': 'item_88',
#   'Tipo': 'type_278',
#   'Descripcion': 'Nombre: item_88   Tipo: type_278   Precio: 59',
#   'Precio': 59},
#  {'Codigo de barras': '0000089',
#   'Nombre': 'item_89',
#   'Tipo': 'type_93',
#   'Descripcion': 'Nombre: item_89   Tipo: type_93   Precio: 964',
#   'Precio': 964},
#  {'Codigo de barras': '0000090',
#   'Nombre': 'item_90',
#   'Tipo': 'type_293',
#   'Descripcion': 'Nombre: item_90   Tipo: type_293   Precio: 584',
#   'Precio': 584},
#  {'Codigo de barras': '0000091',
#   'Nombre': 'item_91',
#   'Tipo': 'type_74',
#   'Descripcion': 'Nombre: item_91   Tipo: type_74   Precio: 695',
#   'Precio': 695},
#  {'Codigo de barras': '0000092',
#   'Nombre': 'item_92',
#   'Tipo': 'type_12',
#   'Descripcion': 'Nombre: item_92   Tipo: type_12   Precio: 277',
#   'Precio': 277},
#  {'Codigo de barras': '0000093',
#   'Nombre': 'item_93',
#   'Tipo': 'type_73',
#   'Descripcion': 'Nombre: item_93   Tipo: type_73   Precio: 261',
#   'Precio': 261},
#  {'Codigo de barras': '0000094',
#   'Nombre': 'item_94',
#   'Tipo': 'type_11',
#   'Descripcion': 'Nombre: item_94   Tipo: type_11   Precio: 117',
#   'Precio': 117},
#  {'Codigo de barras': '0000095',
#   'Nombre': 'item_95',
#   'Tipo': 'type_168',
#   'Descripcion': 'Nombre: item_95   Tipo: type_168   Precio: 389',
#   'Precio': 389},
#  {'Codigo de barras': '0000096',
#   'Nombre': 'item_96',
#   'Tipo': 'type_84',
#   'Descripcion': 'Nombre: item_96   Tipo: type_84   Precio: 232',
#   'Precio': 232},
#  {'Codigo de barras': '0000097',
#   'Nombre': 'item_97',
#   'Tipo': 'type_291',
#   'Descripcion': 'Nombre: item_97   Tipo: type_291   Precio: 395',
#   'Precio': 395},
#  {'Codigo de barras': '0000098',
#   'Nombre': 'item_98',
#   'Tipo': 'type_251',
#   'Descripcion': 'Nombre: item_98   Tipo: type_251   Precio: 624',
#   'Precio': 624},
#  {'Codigo de barras': '0000099',
#   'Nombre': 'item_99',
#   'Tipo': 'type_94',
#   'Descripcion': 'Nombre: item_99   Tipo: type_94   Precio: 191',
#   'Precio': 191},
#  {'Codigo de barras': '0000100',
#   'Nombre': 'item_100',
#   'Tipo': 'type_14',
#   'Descripcion': 'Nombre: item_100   Tipo: type_14   Precio: 87',
#   'Precio': 87},
#  {'Codigo de barras': '0000101',
#   'Nombre': 'item_101',
#   'Tipo': 'type_183',
#   'Descripcion': 'Nombre: item_101   Tipo: type_183   Precio: 602',
#   'Precio': 602},
#  {'Codigo de barras': '0000102',
#   'Nombre': 'item_102',
#   'Tipo': 'type_145',
#   'Descripcion': 'Nombre: item_102   Tipo: type_145   Precio: 117',
#   'Precio': 117},
#  {'Codigo de barras': '0000103',
#   'Nombre': 'item_103',
#   'Tipo': 'type_2',
#   'Descripcion': 'Nombre: item_103   Tipo: type_2   Precio: 839',
#   'Precio': 839},
#  {'Codigo de barras': '0000104',
#   'Nombre': 'item_104',
#   'Tipo': 'type_168',
#   'Descripcion': 'Nombre: item_104   Tipo: type_168   Precio: 628',
#   'Precio': 628},
#  {'Codigo de barras': '0000105',
#   'Nombre': 'item_105',
#   'Tipo': 'type_148',
#   'Descripcion': 'Nombre: item_105   Tipo: type_148   Precio: 324',
#   'Precio': 324},
#  {'Codigo de barras': '0000106',
#   'Nombre': 'item_106',
#   'Tipo': 'type_191',
#   'Descripcion': 'Nombre: item_106   Tipo: type_191   Precio: 994',
#   'Precio': 994},
#  {'Codigo de barras': '0000107',
#   'Nombre': 'item_107',
#   'Tipo': 'type_9',
#   'Descripcion': 'Nombre: item_107   Tipo: type_9   Precio: 301',
#   'Precio': 301},
#  {'Codigo de barras': '0000108',
#   'Nombre': 'item_108',
#   'Tipo': 'type_295',
#   'Descripcion': 'Nombre: item_108   Tipo: type_295   Precio: 600',
#   'Precio': 600},
#  {'Codigo de barras': '0000109',
#   'Nombre': 'item_109',
#   'Tipo': 'type_65',
#   'Descripcion': 'Nombre: item_109   Tipo: type_65   Precio: 132',
#   'Precio': 132},
#  {'Codigo de barras': '0000110',
#   'Nombre': 'item_110',
#   'Tipo': 'type_83',
#   'Descripcion': 'Nombre: item_110   Tipo: type_83   Precio: 334',
#   'Precio': 334},
#  {'Codigo de barras': '0000111',
#   'Nombre': 'item_111',
#   'Tipo': 'type_118',
#   'Descripcion': 'Nombre: item_111   Tipo: type_118   Precio: 374',
#   'Precio': 374},
#  {'Codigo de barras': '0000112',
#   'Nombre': 'item_112',
#   'Tipo': 'type_41',
#   'Descripcion': 'Nombre: item_112   Tipo: type_41   Precio: 171',
#   'Precio': 171},
#  {'Codigo de barras': '0000113',
#   'Nombre': 'item_113',
#   'Tipo': 'type_2',
#   'Descripcion': 'Nombre: item_113   Tipo: type_2   Precio: 1000',
#   'Precio': 1000},
#  {'Codigo de barras': '0000114',
#   'Nombre': 'item_114',
#   'Tipo': 'type_22',
#   'Descripcion': 'Nombre: item_114   Tipo: type_22   Precio: 780',
#   'Precio': 780},
#  {'Codigo de barras': '0000115',
#   'Nombre': 'item_115',
#   'Tipo': 'type_52',
#   'Descripcion': 'Nombre: item_115   Tipo: type_52   Precio: 206',
#   'Precio': 206},
#  {'Codigo de barras': '0000116',
#   'Nombre': 'item_116',
#   'Tipo': 'type_298',
#   'Descripcion': 'Nombre: item_116   Tipo: type_298   Precio: 278',
#   'Precio': 278},
#  {'Codigo de barras': '0000117',
#   'Nombre': 'item_117',
#   'Tipo': 'type_65',
#   'Descripcion': 'Nombre: item_117   Tipo: type_65   Precio: 909',
#   'Precio': 909},
#  {'Codigo de barras': '0000118',
#   'Nombre': 'item_118',
#   'Tipo': 'type_202',
#   'Descripcion': 'Nombre: item_118   Tipo: type_202   Precio: 149',
#   'Precio': 149},
#  {'Codigo de barras': '0000119',
#   'Nombre': 'item_119',
#   'Tipo': 'type_293',
#   'Descripcion': 'Nombre: item_119   Tipo: type_293   Precio: 599',
#   'Precio': 599},
#  {'Codigo de barras': '0000120',
#   'Nombre': 'item_120',
#   'Tipo': 'type_135',
#   'Descripcion': 'Nombre: item_120   Tipo: type_135   Precio: 329',
#   'Precio': 329},
#  {'Codigo de barras': '0000121',
#   'Nombre': 'item_121',
#   'Tipo': 'type_195',
#   'Descripcion': 'Nombre: item_121   Tipo: type_195   Precio: 293',
#   'Precio': 293},
#  {'Codigo de barras': '0000122',
#   'Nombre': 'item_122',
#   'Tipo': 'type_29',
#   'Descripcion': 'Nombre: item_122   Tipo: type_29   Precio: 92',
#   'Precio': 92},
#  {'Codigo de barras': '0000123',
#   'Nombre': 'item_123',
#   'Tipo': 'type_199',
#   'Descripcion': 'Nombre: item_123   Tipo: type_199   Precio: 730',
#   'Precio': 730},
#  {'Codigo de barras': '0000124',
#   'Nombre': 'item_124',
#   'Tipo': 'type_193',
#   'Descripcion': 'Nombre: item_124   Tipo: type_193   Precio: 390',
#   'Precio': 390},
#  {'Codigo de barras': '0000125',
#   'Nombre': 'item_125',
#   'Tipo': 'type_49',
#   'Descripcion': 'Nombre: item_125   Tipo: type_49   Precio: 248',
#   'Precio': 248},
#  {'Codigo de barras': '0000126',
#   'Nombre': 'item_126',
#   'Tipo': 'type_228',
#   'Descripcion': 'Nombre: item_126   Tipo: type_228   Precio: 586',
#   'Precio': 586},
#  {'Codigo de barras': '0000127',
#   'Nombre': 'item_127',
#   'Tipo': 'type_228',
#   'Descripcion': 'Nombre: item_127   Tipo: type_228   Precio: 163',
#   'Precio': 163},
#  {'Codigo de barras': '0000128',
#   'Nombre': 'item_128',
#   'Tipo': 'type_22',
#   'Descripcion': 'Nombre: item_128   Tipo: type_22   Precio: 66',
#   'Precio': 66},
#  {'Codigo de barras': '0000129',
#   'Nombre': 'item_129',
#   'Tipo': 'type_91',
#   'Descripcion': 'Nombre: item_129   Tipo: type_91   Precio: 948',
#   'Precio': 948},
#  {'Codigo de barras': '0000130',
#   'Nombre': 'item_130',
#   'Tipo': 'type_18',
#   'Descripcion': 'Nombre: item_130   Tipo: type_18   Precio: 210',
#   'Precio': 210},
#  {'Codigo de barras': '0000131',
#   'Nombre': 'item_131',
#   'Tipo': 'type_264',
#   'Descripcion': 'Nombre: item_131   Tipo: type_264   Precio: 144',
#   'Precio': 144},
#  {'Codigo de barras': '0000132',
#   'Nombre': 'item_132',
#   'Tipo': 'type_108',
#   'Descripcion': 'Nombre: item_132   Tipo: type_108   Precio: 198',
#   'Precio': 198},
#  {'Codigo de barras': '0000133',
#   'Nombre': 'item_133',
#   'Tipo': 'type_221',
#   'Descripcion': 'Nombre: item_133   Tipo: type_221   Precio: 208',
#   'Precio': 208},
#  {'Codigo de barras': '0000134',
#   'Nombre': 'item_134',
#   'Tipo': 'type_93',
#   'Descripcion': 'Nombre: item_134   Tipo: type_93   Precio: 970',
#   'Precio': 970},
#  {'Codigo de barras': '0000135',
#   'Nombre': 'item_135',
#   'Tipo': 'type_228',
#   'Descripcion': 'Nombre: item_135   Tipo: type_228   Precio: 533',
#   'Precio': 533},
#  {'Codigo de barras': '0000136',
#   'Nombre': 'item_136',
#   'Tipo': 'type_72',
#   'Descripcion': 'Nombre: item_136   Tipo: type_72   Precio: 149',
#   'Precio': 149},
#  {'Codigo de barras': '0000137',
#   'Nombre': 'item_137',
#   'Tipo': 'type_250',
#   'Descripcion': 'Nombre: item_137   Tipo: type_250   Precio: 988',
#   'Precio': 988},
#  {'Codigo de barras': '0000138',
#   'Nombre': 'item_138',
#   'Tipo': 'type_255',
#   'Descripcion': 'Nombre: item_138   Tipo: type_255   Precio: 738',
#   'Precio': 738},
#  {'Codigo de barras': '0000139',
#   'Nombre': 'item_139',
#   'Tipo': 'type_39',
#   'Descripcion': 'Nombre: item_139   Tipo: type_39   Precio: 341',
#   'Precio': 341},
#  {'Codigo de barras': '0000140',
#   'Nombre': 'item_140',
#   'Tipo': 'type_143',
#   'Descripcion': 'Nombre: item_140   Tipo: type_143   Precio: 292',
#   'Precio': 292},
#  {'Codigo de barras': '0000141',
#   'Nombre': 'item_141',
#   'Tipo': 'type_87',
#   'Descripcion': 'Nombre: item_141   Tipo: type_87   Precio: 320',
#   'Precio': 320},
#  {'Codigo de barras': '0000142',
#   'Nombre': 'item_142',
#   'Tipo': 'type_82',
#   'Descripcion': 'Nombre: item_142   Tipo: type_82   Precio: 937',
#   'Precio': 937},
#  {'Codigo de barras': '0000143',
#   'Nombre': 'item_143',
#   'Tipo': 'type_182',
#   'Descripcion': 'Nombre: item_143   Tipo: type_182   Precio: 313',
#   'Precio': 313},
#  {'Codigo de barras': '0000144',
#   'Nombre': 'item_144',
#   'Tipo': 'type_185',
#   'Descripcion': 'Nombre: item_144   Tipo: type_185   Precio: 515',
#   'Precio': 515},
#  {'Codigo de barras': '0000145',
#   'Nombre': 'item_145',
#   'Tipo': 'type_220',
#   'Descripcion': 'Nombre: item_145   Tipo: type_220   Precio: 848',
#   'Precio': 848},
#  {'Codigo de barras': '0000146',
#   'Nombre': 'item_146',
#   'Tipo': 'type_10',
#   'Descripcion': 'Nombre: item_146   Tipo: type_10   Precio: 723',
#   'Precio': 723},
#  {'Codigo de barras': '0000147',
#   'Nombre': 'item_147',
#   'Tipo': 'type_215',
#   'Descripcion': 'Nombre: item_147   Tipo: type_215   Precio: 710',
#   'Precio': 710},
#  {'Codigo de barras': '0000148',
#   'Nombre': 'item_148',
#   'Tipo': 'type_52',
#   'Descripcion': 'Nombre: item_148   Tipo: type_52   Precio: 530',
#   'Precio': 530},
#  {'Codigo de barras': '0000149',
#   'Nombre': 'item_149',
#   'Tipo': 'type_283',
#   'Descripcion': 'Nombre: item_149   Tipo: type_283   Precio: 150',
#   'Precio': 150},
#  {'Codigo de barras': '0000150',
#   'Nombre': 'item_150',
#   'Tipo': 'type_283',
#   'Descripcion': 'Nombre: item_150   Tipo: type_283   Precio: 861',
#   'Precio': 861},
#  {'Codigo de barras': '0000151',
#   'Nombre': 'item_151',
#   'Tipo': 'type_280',
#   'Descripcion': 'Nombre: item_151   Tipo: type_280   Precio: 542',
#   'Precio': 542},
#  {'Codigo de barras': '0000152',
#   'Nombre': 'item_152',
#   'Tipo': 'type_54',
#   'Descripcion': 'Nombre: item_152   Tipo: type_54   Precio: 242',
#   'Precio': 242},
#  {'Codigo de barras': '0000153',
#   'Nombre': 'item_153',
#   'Tipo': 'type_50',
#   'Descripcion': 'Nombre: item_153   Tipo: type_50   Precio: 725',
#   'Precio': 725},
#  {'Codigo de barras': '0000154',
#   'Nombre': 'item_154',
#   'Tipo': 'type_107',
#   'Descripcion': 'Nombre: item_154   Tipo: type_107   Precio: 876',
#   'Precio': 876},
#  {'Codigo de barras': '0000155',
#   'Nombre': 'item_155',
#   'Tipo': 'type_18',
#   'Descripcion': 'Nombre: item_155   Tipo: type_18   Precio: 208',
#   'Precio': 208},
#  {'Codigo de barras': '0000156',
#   'Nombre': 'item_156',
#   'Tipo': 'type_258',
#   'Descripcion': 'Nombre: item_156   Tipo: type_258   Precio: 704',
#   'Precio': 704},
#  {'Codigo de barras': '0000157',
#   'Nombre': 'item_157',
#   'Tipo': 'type_21',
#   'Descripcion': 'Nombre: item_157   Tipo: type_21   Precio: 385',
#   'Precio': 385},
#  {'Codigo de barras': '0000158',
#   'Nombre': 'item_158',
#   'Tipo': 'type_92',
#   'Descripcion': 'Nombre: item_158   Tipo: type_92   Precio: 688',
#   'Precio': 688},
#  {'Codigo de barras': '0000159',
#   'Nombre': 'item_159',
#   'Tipo': 'type_181',
#   'Descripcion': 'Nombre: item_159   Tipo: type_181   Precio: 921',
#   'Precio': 921},
#  {'Codigo de barras': '0000160',
#   'Nombre': 'item_160',
#   'Tipo': 'type_57',
#   'Descripcion': 'Nombre: item_160   Tipo: type_57   Precio: 345',
#   'Precio': 345},
#  {'Codigo de barras': '0000161',
#   'Nombre': 'item_161',
#   'Tipo': 'type_267',
#   'Descripcion': 'Nombre: item_161   Tipo: type_267   Precio: 364',
#   'Precio': 364},
#  {'Codigo de barras': '0000162',
#   'Nombre': 'item_162',
#   'Tipo': 'type_59',
#   'Descripcion': 'Nombre: item_162   Tipo: type_59   Precio: 558',
#   'Precio': 558},
#  {'Codigo de barras': '0000163',
#   'Nombre': 'item_163',
#   'Tipo': 'type_127',
#   'Descripcion': 'Nombre: item_163   Tipo: type_127   Precio: 391',
#   'Precio': 391},
#  {'Codigo de barras': '0000164',
#   'Nombre': 'item_164',
#   'Tipo': 'type_159',
#   'Descripcion': 'Nombre: item_164   Tipo: type_159   Precio: 717',
#   'Precio': 717},
#  {'Codigo de barras': '0000165',
#   'Nombre': 'item_165',
#   'Tipo': 'type_108',
#   'Descripcion': 'Nombre: item_165   Tipo: type_108   Precio: 500',
#   'Precio': 500},
#  {'Codigo de barras': '0000166',
#   'Nombre': 'item_166',
#   'Tipo': 'type_175',
#   'Descripcion': 'Nombre: item_166   Tipo: type_175   Precio: 106',
#   'Precio': 106},
#  {'Codigo de barras': '0000167',
#   'Nombre': 'item_167',
#   'Tipo': 'type_136',
#   'Descripcion': 'Nombre: item_167   Tipo: type_136   Precio: 574',
#   'Precio': 574},
#  {'Codigo de barras': '0000168',
#   'Nombre': 'item_168',
#   'Tipo': 'type_282',
#   'Descripcion': 'Nombre: item_168   Tipo: type_282   Precio: 290',
#   'Precio': 290},
#  {'Codigo de barras': '0000169',
#   'Nombre': 'item_169',
#   'Tipo': 'type_272',
#   'Descripcion': 'Nombre: item_169   Tipo: type_272   Precio: 615',
#   'Precio': 615},
#  {'Codigo de barras': '0000170',
#   'Nombre': 'item_170',
#   'Tipo': 'type_131',
#   'Descripcion': 'Nombre: item_170   Tipo: type_131   Precio: 928',
#   'Precio': 928},
#  {'Codigo de barras': '0000171',
#   'Nombre': 'item_171',
#   'Tipo': 'type_26',
#   'Descripcion': 'Nombre: item_171   Tipo: type_26   Precio: 100',
#   'Precio': 100},
#  {'Codigo de barras': '0000172',
#   'Nombre': 'item_172',
#   'Tipo': 'type_50',
#   'Descripcion': 'Nombre: item_172   Tipo: type_50   Precio: 583',
#   'Precio': 583},
#  {'Codigo de barras': '0000173',
#   'Nombre': 'item_173',
#   'Tipo': 'type_178',
#   'Descripcion': 'Nombre: item_173   Tipo: type_178   Precio: 135',
#   'Precio': 135},
#  {'Codigo de barras': '0000174',
#   'Nombre': 'item_174',
#   'Tipo': 'type_200',
#   'Descripcion': 'Nombre: item_174   Tipo: type_200   Precio: 124',
#   'Precio': 124},
#  {'Codigo de barras': '0000175',
#   'Nombre': 'item_175',
#   'Tipo': 'type_299',
#   'Descripcion': 'Nombre: item_175   Tipo: type_299   Precio: 709',
#   'Precio': 709},
#  {'Codigo de barras': '0000176',
#   'Nombre': 'item_176',
#   'Tipo': 'type_68',
#   'Descripcion': 'Nombre: item_176   Tipo: type_68   Precio: 382',
#   'Precio': 382},
#  {'Codigo de barras': '0000177',
#   'Nombre': 'item_177',
#   'Tipo': 'type_170',
#   'Descripcion': 'Nombre: item_177   Tipo: type_170   Precio: 284',
#   'Precio': 284},
#  {'Codigo de barras': '0000178',
#   'Nombre': 'item_178',
#   'Tipo': 'type_271',
#   'Descripcion': 'Nombre: item_178   Tipo: type_271   Precio: 365',
#   'Precio': 365},
#  {'Codigo de barras': '0000179',
#   'Nombre': 'item_179',
#   'Tipo': 'type_20',
#   'Descripcion': 'Nombre: item_179   Tipo: type_20   Precio: 930',
#   'Precio': 930},
#  {'Codigo de barras': '0000180',
#   'Nombre': 'item_180',
#   'Tipo': 'type_175',
#   'Descripcion': 'Nombre: item_180   Tipo: type_175   Precio: 513',
#   'Precio': 513},
#  {'Codigo de barras': '0000181',
#   'Nombre': 'item_181',
#   'Tipo': 'type_253',
#   'Descripcion': 'Nombre: item_181   Tipo: type_253   Precio: 333',
#   'Precio': 333},
#  {'Codigo de barras': '0000182',
#   'Nombre': 'item_182',
#   'Tipo': 'type_286',
#   'Descripcion': 'Nombre: item_182   Tipo: type_286   Precio: 78',
#   'Precio': 78},
#  {'Codigo de barras': '0000183',
#   'Nombre': 'item_183',
#   'Tipo': 'type_198',
#   'Descripcion': 'Nombre: item_183   Tipo: type_198   Precio: 152',
#   'Precio': 152},
#  {'Codigo de barras': '0000184',
#   'Nombre': 'item_184',
#   'Tipo': 'type_168',
#   'Descripcion': 'Nombre: item_184   Tipo: type_168   Precio: 112',
#   'Precio': 112},
#  {'Codigo de barras': '0000185',
#   'Nombre': 'item_185',
#   'Tipo': 'type_89',
#   'Descripcion': 'Nombre: item_185   Tipo: type_89   Precio: 114',
#   'Precio': 114},
#  {'Codigo de barras': '0000186',
#   'Nombre': 'item_186',
#   'Tipo': 'type_236',
#   'Descripcion': 'Nombre: item_186   Tipo: type_236   Precio: 93',
#   'Precio': 93},
#  {'Codigo de barras': '0000187',
#   'Nombre': 'item_187',
#   'Tipo': 'type_72',
#   'Descripcion': 'Nombre: item_187   Tipo: type_72   Precio: 359',
#   'Precio': 359},
#  {'Codigo de barras': '0000188',
#   'Nombre': 'item_188',
#   'Tipo': 'type_263',
#   'Descripcion': 'Nombre: item_188   Tipo: type_263   Precio: 263',
#   'Precio': 263},
#  {'Codigo de barras': '0000189',
#   'Nombre': 'item_189',
#   'Tipo': 'type_100',
#   'Descripcion': 'Nombre: item_189   Tipo: type_100   Precio: 87',
#   'Precio': 87},
#  {'Codigo de barras': '0000190',
#   'Nombre': 'item_190',
#   'Tipo': 'type_297',
#   'Descripcion': 'Nombre: item_190   Tipo: type_297   Precio: 352',
#   'Precio': 352},
#  {'Codigo de barras': '0000191',
#   'Nombre': 'item_191',
#   'Tipo': 'type_112',
#   'Descripcion': 'Nombre: item_191   Tipo: type_112   Precio: 396',
#   'Precio': 396},
#  {'Codigo de barras': '0000192',
#   'Nombre': 'item_192',
#   'Tipo': 'type_119',
#   'Descripcion': 'Nombre: item_192   Tipo: type_119   Precio: 302',
#   'Precio': 302},
#  {'Codigo de barras': '0000193',
#   'Nombre': 'item_193',
#   'Tipo': 'type_183',
#   'Descripcion': 'Nombre: item_193   Tipo: type_183   Precio: 243',
#   'Precio': 243},
#  {'Codigo de barras': '0000194',
#   'Nombre': 'item_194',
#   'Tipo': 'type_196',
#   'Descripcion': 'Nombre: item_194   Tipo: type_196   Precio: 252',
#   'Precio': 252},
#  {'Codigo de barras': '0000195',
#   'Nombre': 'item_195',
#   'Tipo': 'type_34',
#   'Descripcion': 'Nombre: item_195   Tipo: type_34   Precio: 521',
#   'Precio': 521},
#  {'Codigo de barras': '0000196',
#   'Nombre': 'item_196',
#   'Tipo': 'type_2',
#   'Descripcion': 'Nombre: item_196   Tipo: type_2   Precio: 679',
#   'Precio': 679},
#  {'Codigo de barras': '0000197',
#   'Nombre': 'item_197',
#   'Tipo': 'type_175',
#   'Descripcion': 'Nombre: item_197   Tipo: type_175   Precio: 943',
#   'Precio': 943},
#  {'Codigo de barras': '0000198',
#   'Nombre': 'item_198',
#   'Tipo': 'type_38',
#   'Descripcion': 'Nombre: item_198   Tipo: type_38   Precio: 502',
#   'Precio': 502},
#  {'Codigo de barras': '0000199',
#   'Nombre': 'item_199',
#   'Tipo': 'type_67',
#   'Descripcion': 'Nombre: item_199   Tipo: type_67   Precio: 149',
#   'Precio': 149},
#  {'Codigo de barras': '0000200',
#   'Nombre': 'item_200',
#   'Tipo': 'type_203',
#   'Descripcion': 'Nombre: item_200   Tipo: type_203   Precio: 109',
#   'Precio': 109},
#  {'Codigo de barras': '0000201',
#   'Nombre': 'item_201',
#   'Tipo': 'type_202',
#   'Descripcion': 'Nombre: item_201   Tipo: type_202   Precio: 892',
#   'Precio': 892},
#  {'Codigo de barras': '0000202',
#   'Nombre': 'item_202',
#   'Tipo': 'type_117',
#   'Descripcion': 'Nombre: item_202   Tipo: type_117   Precio: 252',
#   'Precio': 252},
#  {'Codigo de barras': '0000203',
#   'Nombre': 'item_203',
#   'Tipo': 'type_23',
#   'Descripcion': 'Nombre: item_203   Tipo: type_23   Precio: 658',
#   'Precio': 658},
#  {'Codigo de barras': '0000204',
#   'Nombre': 'item_204',
#   'Tipo': 'type_165',
#   'Descripcion': 'Nombre: item_204   Tipo: type_165   Precio: 321',
#   'Precio': 321},
#  {'Codigo de barras': '0000205',
#   'Nombre': 'item_205',
#   'Tipo': 'type_235',
#   'Descripcion': 'Nombre: item_205   Tipo: type_235   Precio: 188',
#   'Precio': 188},
#  {'Codigo de barras': '0000206',
#   'Nombre': 'item_206',
#   'Tipo': 'type_265',
#   'Descripcion': 'Nombre: item_206   Tipo: type_265   Precio: 532',
#   'Precio': 532},
#  {'Codigo de barras': '0000207',
#   'Nombre': 'item_207',
#   'Tipo': 'type_285',
#   'Descripcion': 'Nombre: item_207   Tipo: type_285   Precio: 279',
#   'Precio': 279},
#  {'Codigo de barras': '0000208',
#   'Nombre': 'item_208',
#   'Tipo': 'type_251',
#   'Descripcion': 'Nombre: item_208   Tipo: type_251   Precio: 829',
#   'Precio': 829},
#  {'Codigo de barras': '0000209',
#   'Nombre': 'item_209',
#   'Tipo': 'type_236',
#   'Descripcion': 'Nombre: item_209   Tipo: type_236   Precio: 902',
#   'Precio': 902},
#  {'Codigo de barras': '0000210',
#   'Nombre': 'item_210',
#   'Tipo': 'type_24',
#   'Descripcion': 'Nombre: item_210   Tipo: type_24   Precio: 234',
#   'Precio': 234},
#  {'Codigo de barras': '0000211',
#   'Nombre': 'item_211',
#   'Tipo': 'type_292',
#   'Descripcion': 'Nombre: item_211   Tipo: type_292   Precio: 149',
#   'Precio': 149},
#  {'Codigo de barras': '0000212',
#   'Nombre': 'item_212',
#   'Tipo': 'type_69',
#   'Descripcion': 'Nombre: item_212   Tipo: type_69   Precio: 925',
#   'Precio': 925},
#  {'Codigo de barras': '0000213',
#   'Nombre': 'item_213',
#   'Tipo': 'type_178',
#   'Descripcion': 'Nombre: item_213   Tipo: type_178   Precio: 970',
#   'Precio': 970},
#  {'Codigo de barras': '0000214',
#   'Nombre': 'item_214',
#   'Tipo': 'type_238',
#   'Descripcion': 'Nombre: item_214   Tipo: type_238   Precio: 146',
#   'Precio': 146},
#  {'Codigo de barras': '0000215',
#   'Nombre': 'item_215',
#   'Tipo': 'type_199',
#   'Descripcion': 'Nombre: item_215   Tipo: type_199   Precio: 574',
#   'Precio': 574},
#  {'Codigo de barras': '0000216',
#   'Nombre': 'item_216',
#   'Tipo': 'type_61',
#   'Descripcion': 'Nombre: item_216   Tipo: type_61   Precio: 706',
#   'Precio': 706},
#  {'Codigo de barras': '0000217',
#   'Nombre': 'item_217',
#   'Tipo': 'type_120',
#   'Descripcion': 'Nombre: item_217   Tipo: type_120   Precio: 683',
#   'Precio': 683},
#  {'Codigo de barras': '0000218',
#   'Nombre': 'item_218',
#   'Tipo': 'type_158',
#   'Descripcion': 'Nombre: item_218   Tipo: type_158   Precio: 818',
#   'Precio': 818},
#  {'Codigo de barras': '0000219',
#   'Nombre': 'item_219',
#   'Tipo': 'type_13',
#   'Descripcion': 'Nombre: item_219   Tipo: type_13   Precio: 151',
#   'Precio': 151},
#  {'Codigo de barras': '0000220',
#   'Nombre': 'item_220',
#   'Tipo': 'type_38',
#   'Descripcion': 'Nombre: item_220   Tipo: type_38   Precio: 62',
#   'Precio': 62},
#  {'Codigo de barras': '0000221',
#   'Nombre': 'item_221',
#   'Tipo': 'type_55',
#   'Descripcion': 'Nombre: item_221   Tipo: type_55   Precio: 626',
#   'Precio': 626},
#  {'Codigo de barras': '0000222',
#   'Nombre': 'item_222',
#   'Tipo': 'type_144',
#   'Descripcion': 'Nombre: item_222   Tipo: type_144   Precio: 399',
#   'Precio': 399},
#  {'Codigo de barras': '0000223',
#   'Nombre': 'item_223',
#   'Tipo': 'type_150',
#   'Descripcion': 'Nombre: item_223   Tipo: type_150   Precio: 305',
#   'Precio': 305},
#  {'Codigo de barras': '0000224',
#   'Nombre': 'item_224',
#   'Tipo': 'type_185',
#   'Descripcion': 'Nombre: item_224   Tipo: type_185   Precio: 164',
#   'Precio': 164},
#  {'Codigo de barras': '0000225',
#   'Nombre': 'item_225',
#   'Tipo': 'type_88',
#   'Descripcion': 'Nombre: item_225   Tipo: type_88   Precio: 594',
#   'Precio': 594},
#  {'Codigo de barras': '0000226',
#   'Nombre': 'item_226',
#   'Tipo': 'type_160',
#   'Descripcion': 'Nombre: item_226   Tipo: type_160   Precio: 59',
#   'Precio': 59},
#  {'Codigo de barras': '0000227',
#   'Nombre': 'item_227',
#   'Tipo': 'type_262',
#   'Descripcion': 'Nombre: item_227   Tipo: type_262   Precio: 826',
#   'Precio': 826},
#  {'Codigo de barras': '0000228',
#   'Nombre': 'item_228',
#   'Tipo': 'type_277',
#   'Descripcion': 'Nombre: item_228   Tipo: type_277   Precio: 84',
#   'Precio': 84},
#  {'Codigo de barras': '0000229',
#   'Nombre': 'item_229',
#   'Tipo': 'type_218',
#   'Descripcion': 'Nombre: item_229   Tipo: type_218   Precio: 773',
#   'Precio': 773},
#  {'Codigo de barras': '0000230',
#   'Nombre': 'item_230',
#   'Tipo': 'type_19',
#   'Descripcion': 'Nombre: item_230   Tipo: type_19   Precio: 447',
#   'Precio': 447},
#  {'Codigo de barras': '0000231',
#   'Nombre': 'item_231',
#   'Tipo': 'type_95',
#   'Descripcion': 'Nombre: item_231   Tipo: type_95   Precio: 998',
#   'Precio': 998},
#  {'Codigo de barras': '0000232',
#   'Nombre': 'item_232',
#   'Tipo': 'type_259',
#   'Descripcion': 'Nombre: item_232   Tipo: type_259   Precio: 844',
#   'Precio': 844},
#  {'Codigo de barras': '0000233',
#   'Nombre': 'item_233',
#   'Tipo': 'type_48',
#   'Descripcion': 'Nombre: item_233   Tipo: type_48   Precio: 780',
#   'Precio': 780},
#  {'Codigo de barras': '0000234',
#   'Nombre': 'item_234',
#   'Tipo': 'type_282',
#   'Descripcion': 'Nombre: item_234   Tipo: type_282   Precio: 416',
#   'Precio': 416},
#  {'Codigo de barras': '0000235',
#   'Nombre': 'item_235',
#   'Tipo': 'type_160',
#   'Descripcion': 'Nombre: item_235   Tipo: type_160   Precio: 129',
#   'Precio': 129},
#  {'Codigo de barras': '0000236',
#   'Nombre': 'item_236',
#   'Tipo': 'type_210',
#   'Descripcion': 'Nombre: item_236   Tipo: type_210   Precio: 991',
#   'Precio': 991},
#  {'Codigo de barras': '0000237',
#   'Nombre': 'item_237',
#   'Tipo': 'type_116',
#   'Descripcion': 'Nombre: item_237   Tipo: type_116   Precio: 452',
#   'Precio': 452},
#  {'Codigo de barras': '0000238',
#   'Nombre': 'item_238',
#   'Tipo': 'type_51',
#   'Descripcion': 'Nombre: item_238   Tipo: type_51   Precio: 614',
#   'Precio': 614},
#  {'Codigo de barras': '0000239',
#   'Nombre': 'item_239',
#   'Tipo': 'type_10',
#   'Descripcion': 'Nombre: item_239   Tipo: type_10   Precio: 497',
#   'Precio': 497},
#  {'Codigo de barras': '0000240',
#   'Nombre': 'item_240',
#   'Tipo': 'type_189',
#   'Descripcion': 'Nombre: item_240   Tipo: type_189   Precio: 262',
#   'Precio': 262},
#  {'Codigo de barras': '0000241',
#   'Nombre': 'item_241',
#   'Tipo': 'type_31',
#   'Descripcion': 'Nombre: item_241   Tipo: type_31   Precio: 742',
#   'Precio': 742},
#  {'Codigo de barras': '0000242',
#   'Nombre': 'item_242',
#   'Tipo': 'type_145',
#   'Descripcion': 'Nombre: item_242   Tipo: type_145   Precio: 214',
#   'Precio': 214},
#  {'Codigo de barras': '0000243',
#   'Nombre': 'item_243',
#   'Tipo': 'type_270',
#   'Descripcion': 'Nombre: item_243   Tipo: type_270   Precio: 281',
#   'Precio': 281},
#  {'Codigo de barras': '0000244',
#   'Nombre': 'item_244',
#   'Tipo': 'type_40',
#   'Descripcion': 'Nombre: item_244   Tipo: type_40   Precio: 531',
#   'Precio': 531},
#  {'Codigo de barras': '0000245',
#   'Nombre': 'item_245',
#   'Tipo': 'type_240',
#   'Descripcion': 'Nombre: item_245   Tipo: type_240   Precio: 651',
#   'Precio': 651},
#  {'Codigo de barras': '0000246',
#   'Nombre': 'item_246',
#   'Tipo': 'type_23',
#   'Descripcion': 'Nombre: item_246   Tipo: type_23   Precio: 917',
#   'Precio': 917},
#  {'Codigo de barras': '0000247',
#   'Nombre': 'item_247',
#   'Tipo': 'type_185',
#   'Descripcion': 'Nombre: item_247   Tipo: type_185   Precio: 465',
#   'Precio': 465},
#  {'Codigo de barras': '0000248',
#   'Nombre': 'item_248',
#   'Tipo': 'type_137',
#   'Descripcion': 'Nombre: item_248   Tipo: type_137   Precio: 103',
#   'Precio': 103},
#  {'Codigo de barras': '0000249',
#   'Nombre': 'item_249',
#   'Tipo': 'type_220',
#   'Descripcion': 'Nombre: item_249   Tipo: type_220   Precio: 501',
#   'Precio': 501},
#  {'Codigo de barras': '0000250',
#   'Nombre': 'item_250',
#   'Tipo': 'type_49',
#   'Descripcion': 'Nombre: item_250   Tipo: type_49   Precio: 78',
#   'Precio': 78},
#  {'Codigo de barras': '0000251',
#   'Nombre': 'item_251',
#   'Tipo': 'type_68',
#   'Descripcion': 'Nombre: item_251   Tipo: type_68   Precio: 93',
#   'Precio': 93},
#  {'Codigo de barras': '0000252',
#   'Nombre': 'item_252',
#   'Tipo': 'type_24',
#   'Descripcion': 'Nombre: item_252   Tipo: type_24   Precio: 894',
#   'Precio': 894},
#  {'Codigo de barras': '0000253',
#   'Nombre': 'item_253',
#   'Tipo': 'type_77',
#   'Descripcion': 'Nombre: item_253   Tipo: type_77   Precio: 815',
#   'Precio': 815},
#  {'Codigo de barras': '0000254',
#   'Nombre': 'item_254',
#   'Tipo': 'type_127',
#   'Descripcion': 'Nombre: item_254   Tipo: type_127   Precio: 760',
#   'Precio': 760},
#  {'Codigo de barras': '0000255',
#   'Nombre': 'item_255',
#   'Tipo': 'type_146',
#   'Descripcion': 'Nombre: item_255   Tipo: type_146   Precio: 430',
#   'Precio': 430},
#  {'Codigo de barras': '0000256',
#   'Nombre': 'item_256',
#   'Tipo': 'type_283',
#   'Descripcion': 'Nombre: item_256   Tipo: type_283   Precio: 935',
#   'Precio': 935},
#  {'Codigo de barras': '0000257',
#   'Nombre': 'item_257',
#   'Tipo': 'type_87',
#   'Descripcion': 'Nombre: item_257   Tipo: type_87   Precio: 432',
#   'Precio': 432},
#  {'Codigo de barras': '0000258',
#   'Nombre': 'item_258',
#   'Tipo': 'type_33',
#   'Descripcion': 'Nombre: item_258   Tipo: type_33   Precio: 851',
#   'Precio': 851},
#  {'Codigo de barras': '0000259',
#   'Nombre': 'item_259',
#   'Tipo': 'type_24',
#   'Descripcion': 'Nombre: item_259   Tipo: type_24   Precio: 703',
#   'Precio': 703},
#  {'Codigo de barras': '0000260',
#   'Nombre': 'item_260',
#   'Tipo': 'type_149',
#   'Descripcion': 'Nombre: item_260   Tipo: type_149   Precio: 74',
#   'Precio': 74},
#  {'Codigo de barras': '0000261',
#   'Nombre': 'item_261',
#   'Tipo': 'type_235',
#   'Descripcion': 'Nombre: item_261   Tipo: type_235   Precio: 744',
#   'Precio': 744},
#  {'Codigo de barras': '0000262',
#   'Nombre': 'item_262',
#   'Tipo': 'type_243',
#   'Descripcion': 'Nombre: item_262   Tipo: type_243   Precio: 415',
#   'Precio': 415},
#  {'Codigo de barras': '0000263',
#   'Nombre': 'item_263',
#   'Tipo': 'type_11',
#   'Descripcion': 'Nombre: item_263   Tipo: type_11   Precio: 192',
#   'Precio': 192},
#  {'Codigo de barras': '0000264',
#   'Nombre': 'item_264',
#   'Tipo': 'type_191',
#   'Descripcion': 'Nombre: item_264   Tipo: type_191   Precio: 262',
#   'Precio': 262},
#  {'Codigo de barras': '0000265',
#   'Nombre': 'item_265',
#   'Tipo': 'type_232',
#   'Descripcion': 'Nombre: item_265   Tipo: type_232   Precio: 526',
#   'Precio': 526},
#  {'Codigo de barras': '0000266',
#   'Nombre': 'item_266',
#   'Tipo': 'type_10',
#   'Descripcion': 'Nombre: item_266   Tipo: type_10   Precio: 462',
#   'Precio': 462},
#  {'Codigo de barras': '0000267',
#   'Nombre': 'item_267',
#   'Tipo': 'type_269',
#   'Descripcion': 'Nombre: item_267   Tipo: type_269   Precio: 316',
#   'Precio': 316},
#  {'Codigo de barras': '0000268',
#   'Nombre': 'item_268',
#   'Tipo': 'type_259',
#   'Descripcion': 'Nombre: item_268   Tipo: type_259   Precio: 544',
#   'Precio': 544},
#  {'Codigo de barras': '0000269',
#   'Nombre': 'item_269',
#   'Tipo': 'type_128',
#   'Descripcion': 'Nombre: item_269   Tipo: type_128   Precio: 131',
#   'Precio': 131},
#  {'Codigo de barras': '0000270',
#   'Nombre': 'item_270',
#   'Tipo': 'type_118',
#   'Descripcion': 'Nombre: item_270   Tipo: type_118   Precio: 655',
#   'Precio': 655},
#  {'Codigo de barras': '0000271',
#   'Nombre': 'item_271',
#   'Tipo': 'type_70',
#   'Descripcion': 'Nombre: item_271   Tipo: type_70   Precio: 706',
#   'Precio': 706},
#  {'Codigo de barras': '0000272',
#   'Nombre': 'item_272',
#   'Tipo': 'type_183',
#   'Descripcion': 'Nombre: item_272   Tipo: type_183   Precio: 819',
#   'Precio': 819},
#  {'Codigo de barras': '0000273',
#   'Nombre': 'item_273',
#   'Tipo': 'type_228',
#   'Descripcion': 'Nombre: item_273   Tipo: type_228   Precio: 901',
#   'Precio': 901},
#  {'Codigo de barras': '0000274',
#   'Nombre': 'item_274',
#   'Tipo': 'type_118',
#   'Descripcion': 'Nombre: item_274   Tipo: type_118   Precio: 304',
#   'Precio': 304},
#  {'Codigo de barras': '0000275',
#   'Nombre': 'item_275',
#   'Tipo': 'type_196',
#   'Descripcion': 'Nombre: item_275   Tipo: type_196   Precio: 248',
#   'Precio': 248},
#  {'Codigo de barras': '0000276',
#   'Nombre': 'item_276',
#   'Tipo': 'type_112',
#   'Descripcion': 'Nombre: item_276   Tipo: type_112   Precio: 458',
#   'Precio': 458},
#  {'Codigo de barras': '0000277',
#   'Nombre': 'item_277',
#   'Tipo': 'type_80',
#   'Descripcion': 'Nombre: item_277   Tipo: type_80   Precio: 149',
#   'Precio': 149},
#  {'Codigo de barras': '0000278',
#   'Nombre': 'item_278',
#   'Tipo': 'type_98',
#   'Descripcion': 'Nombre: item_278   Tipo: type_98   Precio: 778',
#   'Precio': 778},
#  {'Codigo de barras': '0000279',
#   'Nombre': 'item_279',
#   'Tipo': 'type_73',
#   'Descripcion': 'Nombre: item_279   Tipo: type_73   Precio: 717',
#   'Precio': 717},
#  {'Codigo de barras': '0000280',
#   'Nombre': 'item_280',
#   'Tipo': 'type_258',
#   'Descripcion': 'Nombre: item_280   Tipo: type_258   Precio: 109',
#   'Precio': 109},
#  {'Codigo de barras': '0000281',
#   'Nombre': 'item_281',
#   'Tipo': 'type_261',
#   'Descripcion': 'Nombre: item_281   Tipo: type_261   Precio: 873',
#   'Precio': 873},
#  {'Codigo de barras': '0000282',
#   'Nombre': 'item_282',
#   'Tipo': 'type_297',
#   'Descripcion': 'Nombre: item_282   Tipo: type_297   Precio: 116',
#   'Precio': 116},
#  {'Codigo de barras': '0000283',
#   'Nombre': 'item_283',
#   'Tipo': 'type_60',
#   'Descripcion': 'Nombre: item_283   Tipo: type_60   Precio: 285',
#   'Precio': 285},
#  {'Codigo de barras': '0000284',
#   'Nombre': 'item_284',
#   'Tipo': 'type_236',
#   'Descripcion': 'Nombre: item_284   Tipo: type_236   Precio: 334',
#   'Precio': 334},
#  {'Codigo de barras': '0000285',
#   'Nombre': 'item_285',
#   'Tipo': 'type_250',
#   'Descripcion': 'Nombre: item_285   Tipo: type_250   Precio: 319',
#   'Precio': 319},
#  {'Codigo de barras': '0000286',
#   'Nombre': 'item_286',
#   'Tipo': 'type_62',
#   'Descripcion': 'Nombre: item_286   Tipo: type_62   Precio: 785',
#   'Precio': 785},
#  {'Codigo de barras': '0000287',
#   'Nombre': 'item_287',
#   'Tipo': 'type_247',
#   'Descripcion': 'Nombre: item_287   Tipo: type_247   Precio: 975',
#   'Precio': 975},
#  {'Codigo de barras': '0000288',
#   'Nombre': 'item_288',
#   'Tipo': 'type_201',
#   'Descripcion': 'Nombre: item_288   Tipo: type_201   Precio: 778',
#   'Precio': 778},
#  {'Codigo de barras': '0000289',
#   'Nombre': 'item_289',
#   'Tipo': 'type_23',
#   'Descripcion': 'Nombre: item_289   Tipo: type_23   Precio: 868',
#   'Precio': 868},
#  {'Codigo de barras': '0000290',
#   'Nombre': 'item_290',
#   'Tipo': 'type_120',
#   'Descripcion': 'Nombre: item_290   Tipo: type_120   Precio: 810',
#   'Precio': 810},
#  {'Codigo de barras': '0000291',
#   'Nombre': 'item_291',
#   'Tipo': 'type_255',
#   'Descripcion': 'Nombre: item_291   Tipo: type_255   Precio: 420',
#   'Precio': 420},
#  {'Codigo de barras': '0000292',
#   'Nombre': 'item_292',
#   'Tipo': 'type_162',
#   'Descripcion': 'Nombre: item_292   Tipo: type_162   Precio: 804',
#   'Precio': 804},
#  {'Codigo de barras': '0000293',
#   'Nombre': 'item_293',
#   'Tipo': 'type_136',
#   'Descripcion': 'Nombre: item_293   Tipo: type_136   Precio: 286',
#   'Precio': 286},
#  {'Codigo de barras': '0000294',
#   'Nombre': 'item_294',
#   'Tipo': 'type_4',
# ...
#   'Precio': 571},
#  {'Codigo de barras': '0000904',
#   'Nombre': 'item_904',
#   'Tipo': 'type_278',
#   'Descripcion': 'Nombre: item_904   Tipo: type_278   Precio: 731',
#   'Precio': 731},
#  {'Codigo de barras': '0000905',
#   'Nombre': 'item_905',
#   'Tipo': 'type_195',
#   'Descripcion': 'Nombre: item_905   Tipo: type_195   Precio: 866',
#   'Precio': 866},
#  {'Codigo de barras': '0000906',
#   'Nombre': 'item_906',
#   'Tipo': 'type_79',
#   'Descripcion': 'Nombre: item_906   Tipo: type_79   Precio: 338',
#   'Precio': 338},
#  {'Codigo de barras': '0000907',
#   'Nombre': 'item_907',
#   'Tipo': 'type_248',
#   'Descripcion': 'Nombre: item_907   Tipo: type_248   Precio: 872',
#   'Precio': 872},
#  {'Codigo de barras': '0000908',
#   'Nombre': 'item_908',
#   'Tipo': 'type_216',
#   'Descripcion': 'Nombre: item_908   Tipo: type_216   Precio: 360',
#   'Precio': 360},
#  {'Codigo de barras': '0000909',
#   'Nombre': 'item_909',
#   'Tipo': 'type_78',
#   'Descripcion': 'Nombre: item_909   Tipo: type_78   Precio: 634',
#   'Precio': 634},
#  {'Codigo de barras': '0000910',
#   'Nombre': 'item_910',
#   'Tipo': 'type_230',
#   'Descripcion': 'Nombre: item_910   Tipo: type_230   Precio: 324',
#   'Precio': 324},
#  {'Codigo de barras': '0000911',
#   'Nombre': 'item_911',
#   'Tipo': 'type_87',
#   'Descripcion': 'Nombre: item_911   Tipo: type_87   Precio: 467',
#   'Precio': 467},
#  {'Codigo de barras': '0000912',
#   'Nombre': 'item_912',
#   'Tipo': 'type_230',
#   'Descripcion': 'Nombre: item_912   Tipo: type_230   Precio: 110',
#   'Precio': 110},
#  {'Codigo de barras': '0000913',
#   'Nombre': 'item_913',
#   'Tipo': 'type_297',
#   'Descripcion': 'Nombre: item_913   Tipo: type_297   Precio: 496',
#   'Precio': 496},
#  {'Codigo de barras': '0000914',
#   'Nombre': 'item_914',
#   'Tipo': 'type_179',
#   'Descripcion': 'Nombre: item_914   Tipo: type_179   Precio: 126',
#   'Precio': 126},
#  {'Codigo de barras': '0000915',
#   'Nombre': 'item_915',
#   'Tipo': 'type_226',
#   'Descripcion': 'Nombre: item_915   Tipo: type_226   Precio: 391',
#   'Precio': 391},
#  {'Codigo de barras': '0000916',
#   'Nombre': 'item_916',
#   'Tipo': 'type_124',
#   'Descripcion': 'Nombre: item_916   Tipo: type_124   Precio: 998',
#   'Precio': 998},
#  {'Codigo de barras': '0000917',
#   'Nombre': 'item_917',
#   'Tipo': 'type_242',
#   'Descripcion': 'Nombre: item_917   Tipo: type_242   Precio: 154',
#   'Precio': 154},
#  {'Codigo de barras': '0000918',
#   'Nombre': 'item_918',
#   'Tipo': 'type_37',
#   'Descripcion': 'Nombre: item_918   Tipo: type_37   Precio: 568',
#   'Precio': 568},
#  {'Codigo de barras': '0000919',
#   'Nombre': 'item_919',
#   'Tipo': 'type_257',
#   'Descripcion': 'Nombre: item_919   Tipo: type_257   Precio: 1000',
#   'Precio': 1000},
#  {'Codigo de barras': '0000920',
#   'Nombre': 'item_920',
#   'Tipo': 'type_213',
#   'Descripcion': 'Nombre: item_920   Tipo: type_213   Precio: 510',
#   'Precio': 510},
#  {'Codigo de barras': '0000921',
#   'Nombre': 'item_921',
#   'Tipo': 'type_176',
#   'Descripcion': 'Nombre: item_921   Tipo: type_176   Precio: 341',
#   'Precio': 341},
#  {'Codigo de barras': '0000922',
#   'Nombre': 'item_922',
#   'Tipo': 'type_276',
#   'Descripcion': 'Nombre: item_922   Tipo: type_276   Precio: 56',
#   'Precio': 56},
#  {'Codigo de barras': '0000923',
#   'Nombre': 'item_923',
#   'Tipo': 'type_266',
#   'Descripcion': 'Nombre: item_923   Tipo: type_266   Precio: 113',
#   'Precio': 113},
#  {'Codigo de barras': '0000924',
#   'Nombre': 'item_924',
#   'Tipo': 'type_109',
#   'Descripcion': 'Nombre: item_924   Tipo: type_109   Precio: 486',
#   'Precio': 486},
#  {'Codigo de barras': '0000925',
#   'Nombre': 'item_925',
#   'Tipo': 'type_264',
#   'Descripcion': 'Nombre: item_925   Tipo: type_264   Precio: 634',
#   'Precio': 634},
#  {'Codigo de barras': '0000926',
#   'Nombre': 'item_926',
#   'Tipo': 'type_24',
#   'Descripcion': 'Nombre: item_926   Tipo: type_24   Precio: 808',
#   'Precio': 808},
#  {'Codigo de barras': '0000927',
#   'Nombre': 'item_927',
#   'Tipo': 'type_280',
#   'Descripcion': 'Nombre: item_927   Tipo: type_280   Precio: 425',
#   'Precio': 425},
#  {'Codigo de barras': '0000928',
#   'Nombre': 'item_928',
#   'Tipo': 'type_67',
#   'Descripcion': 'Nombre: item_928   Tipo: type_67   Precio: 661',
#   'Precio': 661},
#  {'Codigo de barras': '0000929',
#   'Nombre': 'item_929',
#   'Tipo': 'type_119',
#   'Descripcion': 'Nombre: item_929   Tipo: type_119   Precio: 240',
#   'Precio': 240},
#  {'Codigo de barras': '0000930',
#   'Nombre': 'item_930',
#   'Tipo': 'type_19',
#   'Descripcion': 'Nombre: item_930   Tipo: type_19   Precio: 428',
#   'Precio': 428},
#  {'Codigo de barras': '0000931',
#   'Nombre': 'item_931',
#   'Tipo': 'type_206',
#   'Descripcion': 'Nombre: item_931   Tipo: type_206   Precio: 299',
#   'Precio': 299},
#  {'Codigo de barras': '0000932',
#   'Nombre': 'item_932',
#   'Tipo': 'type_17',
#   'Descripcion': 'Nombre: item_932   Tipo: type_17   Precio: 705',
#   'Precio': 705},
#  {'Codigo de barras': '0000933',
#   'Nombre': 'item_933',
#   'Tipo': 'type_232',
#   'Descripcion': 'Nombre: item_933   Tipo: type_232   Precio: 846',
#   'Precio': 846},
#  {'Codigo de barras': '0000934',
#   'Nombre': 'item_934',
#   'Tipo': 'type_159',
#   'Descripcion': 'Nombre: item_934   Tipo: type_159   Precio: 642',
#   'Precio': 642},
#  {'Codigo de barras': '0000935',
#   'Nombre': 'item_935',
#   'Tipo': 'type_271',
#   'Descripcion': 'Nombre: item_935   Tipo: type_271   Precio: 513',
#   'Precio': 513},
#  {'Codigo de barras': '0000936',
#   'Nombre': 'item_936',
#   'Tipo': 'type_123',
#   'Descripcion': 'Nombre: item_936   Tipo: type_123   Precio: 203',
#   'Precio': 203},
#  {'Codigo de barras': '0000937',
#   'Nombre': 'item_937',
#   'Tipo': 'type_68',
#   'Descripcion': 'Nombre: item_937   Tipo: type_68   Precio: 658',
#   'Precio': 658},
#  {'Codigo de barras': '0000938',
#   'Nombre': 'item_938',
#   'Tipo': 'type_10',
#   'Descripcion': 'Nombre: item_938   Tipo: type_10   Precio: 967',
#   'Precio': 967},
#  {'Codigo de barras': '0000939',
#   'Nombre': 'item_939',
#   'Tipo': 'type_240',
#   'Descripcion': 'Nombre: item_939   Tipo: type_240   Precio: 822',
#   'Precio': 822},
#  {'Codigo de barras': '0000940',
#   'Nombre': 'item_940',
#   'Tipo': 'type_180',
#   'Descripcion': 'Nombre: item_940   Tipo: type_180   Precio: 515',
#   'Precio': 515},
#  {'Codigo de barras': '0000941',
#   'Nombre': 'item_941',
#   'Tipo': 'type_163',
#   'Descripcion': 'Nombre: item_941   Tipo: type_163   Precio: 450',
#   'Precio': 450},
#  {'Codigo de barras': '0000942',
#   'Nombre': 'item_942',
#   'Tipo': 'type_100',
#   'Descripcion': 'Nombre: item_942   Tipo: type_100   Precio: 905',
#   'Precio': 905},
#  {'Codigo de barras': '0000943',
#   'Nombre': 'item_943',
#   'Tipo': 'type_40',
#   'Descripcion': 'Nombre: item_943   Tipo: type_40   Precio: 715',
#   'Precio': 715},
#  {'Codigo de barras': '0000944',
#   'Nombre': 'item_944',
#   'Tipo': 'type_38',
#   'Descripcion': 'Nombre: item_944   Tipo: type_38   Precio: 613',
#   'Precio': 613},
#  {'Codigo de barras': '0000945',
#   'Nombre': 'item_945',
#   'Tipo': 'type_286',
#   'Descripcion': 'Nombre: item_945   Tipo: type_286   Precio: 663',
#   'Precio': 663},
#  {'Codigo de barras': '0000946',
#   'Nombre': 'item_946',
#   'Tipo': 'type_180',
#   'Descripcion': 'Nombre: item_946   Tipo: type_180   Precio: 610',
#   'Precio': 610},
#  {'Codigo de barras': '0000947',
#   'Nombre': 'item_947',
#   'Tipo': 'type_3',
#   'Descripcion': 'Nombre: item_947   Tipo: type_3   Precio: 74',
#   'Precio': 74},
#  {'Codigo de barras': '0000948',
#   'Nombre': 'item_948',
#   'Tipo': 'type_72',
#   'Descripcion': 'Nombre: item_948   Tipo: type_72   Precio: 918',
#   'Precio': 918},
#  {'Codigo de barras': '0000949',
#   'Nombre': 'item_949',
#   'Tipo': 'type_99',
#   'Descripcion': 'Nombre: item_949   Tipo: type_99   Precio: 306',
#   'Precio': 306},
#  {'Codigo de barras': '0000950',
#   'Nombre': 'item_950',
#   'Tipo': 'type_57',
#   'Descripcion': 'Nombre: item_950   Tipo: type_57   Precio: 806',
#   'Precio': 806},
#  {'Codigo de barras': '0000951',
#   'Nombre': 'item_951',
#   'Tipo': 'type_124',
#   'Descripcion': 'Nombre: item_951   Tipo: type_124   Precio: 530',
#   'Precio': 530},
#  {'Codigo de barras': '0000952',
#   'Nombre': 'item_952',
#   'Tipo': 'type_5',
#   'Descripcion': 'Nombre: item_952   Tipo: type_5   Precio: 835',
#   'Precio': 835},
#  {'Codigo de barras': '0000953',
#   'Nombre': 'item_953',
#   'Tipo': 'type_267',
#   'Descripcion': 'Nombre: item_953   Tipo: type_267   Precio: 578',
#   'Precio': 578},
#  {'Codigo de barras': '0000954',
#   'Nombre': 'item_954',
#   'Tipo': 'type_209',
#   'Descripcion': 'Nombre: item_954   Tipo: type_209   Precio: 970',
#   'Precio': 970},
#  {'Codigo de barras': '0000955',
#   'Nombre': 'item_955',
#   'Tipo': 'type_299',
#   'Descripcion': 'Nombre: item_955   Tipo: type_299   Precio: 182',
#   'Precio': 182},
#  {'Codigo de barras': '0000956',
#   'Nombre': 'item_956',
#   'Tipo': 'type_108',
#   'Descripcion': 'Nombre: item_956   Tipo: type_108   Precio: 84',
#   'Precio': 84},
#  {'Codigo de barras': '0000957',
#   'Nombre': 'item_957',
#   'Tipo': 'type_180',
#   'Descripcion': 'Nombre: item_957   Tipo: type_180   Precio: 97',
#   'Precio': 97},
#  {'Codigo de barras': '0000958',
#   'Nombre': 'item_958',
#   'Tipo': 'type_157',
#   'Descripcion': 'Nombre: item_958   Tipo: type_157   Precio: 531',
#   'Precio': 531},
#  {'Codigo de barras': '0000959',
#   'Nombre': 'item_959',
#   'Tipo': 'type_281',
#   'Descripcion': 'Nombre: item_959   Tipo: type_281   Precio: 421',
#   'Precio': 421},
#  {'Codigo de barras': '0000960',
#   'Nombre': 'item_960',
#   'Tipo': 'type_180',
#   'Descripcion': 'Nombre: item_960   Tipo: type_180   Precio: 882',
#   'Precio': 882},
#  {'Codigo de barras': '0000961',
#   'Nombre': 'item_961',
#   'Tipo': 'type_103',
#   'Descripcion': 'Nombre: item_961   Tipo: type_103   Precio: 337',
#   'Precio': 337},
#  {'Codigo de barras': '0000962',
#   'Nombre': 'item_962',
#   'Tipo': 'type_50',
#   'Descripcion': 'Nombre: item_962   Tipo: type_50   Precio: 458',
#   'Precio': 458},
#  {'Codigo de barras': '0000963',
#   'Nombre': 'item_963',
#   'Tipo': 'type_178',
#   'Descripcion': 'Nombre: item_963   Tipo: type_178   Precio: 513',
#   'Precio': 513},
#  {'Codigo de barras': '0000964',
#   'Nombre': 'item_964',
#   'Tipo': 'type_18',
#   'Descripcion': 'Nombre: item_964   Tipo: type_18   Precio: 51',
#   'Precio': 51},
#  {'Codigo de barras': '0000965',
#   'Nombre': 'item_965',
#   'Tipo': 'type_22',
#   'Descripcion': 'Nombre: item_965   Tipo: type_22   Precio: 920',
#   'Precio': 920},
#  {'Codigo de barras': '0000966',
#   'Nombre': 'item_966',
#   'Tipo': 'type_52',
#   'Descripcion': 'Nombre: item_966   Tipo: type_52   Precio: 964',
#   'Precio': 964},
#  {'Codigo de barras': '0000967',
#   'Nombre': 'item_967',
#   'Tipo': 'type_36',
#   'Descripcion': 'Nombre: item_967   Tipo: type_36   Precio: 483',
#   'Precio': 483},
#  {'Codigo de barras': '0000968',
#   'Nombre': 'item_968',
#   'Tipo': 'type_189',
#   'Descripcion': 'Nombre: item_968   Tipo: type_189   Precio: 319',
#   'Precio': 319},
#  {'Codigo de barras': '0000969',
#   'Nombre': 'item_969',
#   'Tipo': 'type_169',
#   'Descripcion': 'Nombre: item_969   Tipo: type_169   Precio: 849',
#   'Precio': 849},
#  {'Codigo de barras': '0000970',
#   'Nombre': 'item_970',
#   'Tipo': 'type_217',
#   'Descripcion': 'Nombre: item_970   Tipo: type_217   Precio: 188',
#   'Precio': 188},
#  {'Codigo de barras': '0000971',
#   'Nombre': 'item_971',
#   'Tipo': 'type_89',
#   'Descripcion': 'Nombre: item_971   Tipo: type_89   Precio: 647',
#   'Precio': 647},
#  {'Codigo de barras': '0000972',
#   'Nombre': 'item_972',
#   'Tipo': 'type_58',
#   'Descripcion': 'Nombre: item_972   Tipo: type_58   Precio: 568',
#   'Precio': 568},
#  {'Codigo de barras': '0000973',
#   'Nombre': 'item_973',
#   'Tipo': 'type_210',
#   'Descripcion': 'Nombre: item_973   Tipo: type_210   Precio: 667',
#   'Precio': 667},
#  {'Codigo de barras': '0000974',
#   'Nombre': 'item_974',
#   'Tipo': 'type_122',
#   'Descripcion': 'Nombre: item_974   Tipo: type_122   Precio: 747',
#   'Precio': 747},
#  {'Codigo de barras': '0000975',
#   'Nombre': 'item_975',
#   'Tipo': 'type_216',
#   'Descripcion': 'Nombre: item_975   Tipo: type_216   Precio: 816',
#   'Precio': 816},
#  {'Codigo de barras': '0000976',
#   'Nombre': 'item_976',
#   'Tipo': 'type_182',
#   'Descripcion': 'Nombre: item_976   Tipo: type_182   Precio: 537',
#   'Precio': 537},
#  {'Codigo de barras': '0000977',
#   'Nombre': 'item_977',
#   'Tipo': 'type_266',
#   'Descripcion': 'Nombre: item_977   Tipo: type_266   Precio: 381',
#   'Precio': 381},
#  {'Codigo de barras': '0000978',
#   'Nombre': 'item_978',
#   'Tipo': 'type_24',
#   'Descripcion': 'Nombre: item_978   Tipo: type_24   Precio: 184',
#   'Precio': 184},
#  {'Codigo de barras': '0000979',
#   'Nombre': 'item_979',
#   'Tipo': 'type_281',
#   'Descripcion': 'Nombre: item_979   Tipo: type_281   Precio: 361',
#   'Precio': 361},
#  {'Codigo de barras': '0000980',
#   'Nombre': 'item_980',
#   'Tipo': 'type_140',
#   'Descripcion': 'Nombre: item_980   Tipo: type_140   Precio: 510',
#   'Precio': 510},
#  {'Codigo de barras': '0000981',
#   'Nombre': 'item_981',
#   'Tipo': 'type_24',
#   'Descripcion': 'Nombre: item_981   Tipo: type_24   Precio: 402',
#   'Precio': 402},
#  {'Codigo de barras': '0000982',
#   'Nombre': 'item_982',
#   'Tipo': 'type_57',
#   'Descripcion': 'Nombre: item_982   Tipo: type_57   Precio: 946',
#   'Precio': 946},
#  {'Codigo de barras': '0000983',
#   'Nombre': 'item_983',
#   'Tipo': 'type_84',
#   'Descripcion': 'Nombre: item_983   Tipo: type_84   Precio: 963',
#   'Precio': 963},
#  {'Codigo de barras': '0000984',
#   'Nombre': 'item_984',
#   'Tipo': 'type_231',
#   'Descripcion': 'Nombre: item_984   Tipo: type_231   Precio: 106',
#   'Precio': 106},
#  {'Codigo de barras': '0000985',
#   'Nombre': 'item_985',
#   'Tipo': 'type_24',
#   'Descripcion': 'Nombre: item_985   Tipo: type_24   Precio: 52',
#   'Precio': 52},
#  {'Codigo de barras': '0000986',
#   'Nombre': 'item_986',
#   'Tipo': 'type_172',
#   'Descripcion': 'Nombre: item_986   Tipo: type_172   Precio: 877',
#   'Precio': 877},
#  {'Codigo de barras': '0000987',
#   'Nombre': 'item_987',
#   'Tipo': 'type_179',
#   'Descripcion': 'Nombre: item_987   Tipo: type_179   Precio: 235',
#   'Precio': 235},
#  {'Codigo de barras': '0000988',
#   'Nombre': 'item_988',
#   'Tipo': 'type_102',
#   'Descripcion': 'Nombre: item_988   Tipo: type_102   Precio: 360',
#   'Precio': 360},
#  {'Codigo de barras': '0000989',
#   'Nombre': 'item_989',
#   'Tipo': 'type_131',
#   'Descripcion': 'Nombre: item_989   Tipo: type_131   Precio: 66',
#   'Precio': 66},
#  {'Codigo de barras': '0000990',
#   'Nombre': 'item_990',
#   'Tipo': 'type_150',
#   'Descripcion': 'Nombre: item_990   Tipo: type_150   Precio: 584',
#   'Precio': 584},
#  {'Codigo de barras': '0000991',
#   'Nombre': 'item_991',
#   'Tipo': 'type_138',
#   'Descripcion': 'Nombre: item_991   Tipo: type_138   Precio: 134',
#   'Precio': 134},
#  {'Codigo de barras': '0000992',
#   'Nombre': 'item_992',
#   'Tipo': 'type_111',
#   'Descripcion': 'Nombre: item_992   Tipo: type_111   Precio: 800',
#   'Precio': 800},
#  {'Codigo de barras': '0000993',
#   'Nombre': 'item_993',
#   'Tipo': 'type_10',
#   'Descripcion': 'Nombre: item_993   Tipo: type_10   Precio: 926',
#   'Precio': 926},
#  {'Codigo de barras': '0000994',
#   'Nombre': 'item_994',
#   'Tipo': 'type_138',
#   'Descripcion': 'Nombre: item_994   Tipo: type_138   Precio: 643',
#   'Precio': 643},
#  {'Codigo de barras': '0000995',
#   'Nombre': 'item_995',
#   'Tipo': 'type_195',
#   'Descripcion': 'Nombre: item_995   Tipo: type_195   Precio: 69',
#   'Precio': 69},
#  {'Codigo de barras': '0000996',
#   'Nombre': 'item_996',
#   'Tipo': 'type_233',
#   'Descripcion': 'Nombre: item_996   Tipo: type_233   Precio: 877',
#   'Precio': 877},
#  {'Codigo de barras': '0000997',
#   'Nombre': 'item_997',
#   'Tipo': 'type_117',
#   'Descripcion': 'Nombre: item_997   Tipo: type_117   Precio: 873',
#   'Precio': 873},
#  {'Codigo de barras': '0000998',
#   'Nombre': 'item_998',
#   'Tipo': 'type_113',
#   'Descripcion': 'Nombre: item_998   Tipo: type_113   Precio: 405',
#   'Precio': 405},
#  {'Codigo de barras': '0000999',
#   'Nombre': 'item_999',
#   'Tipo': 'type_170',
#   'Descripcion': 'Nombre: item_999   Tipo: type_170   Precio: 958',
#   'Precio': 958},
#  {'Codigo de barras': '0001000',
#   'Nombre': 'item_1000',
#   'Tipo': 'type_271',
#   'Descripcion': 'Nombre: item_1000   Tipo: type_271   Precio: 64',
#   'Precio': 64},
#  ...]

# %%
df = pd.DataFrame.from_dict(dict_items, index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-9338ad8931ac> in <module>
# ----> 1 df = pd.DataFrame.from_dict(dict_items, index=False)
#       2 df
#
# TypeError: from_dict() got an unexpected keyword argument 'index'

# %%
df.to_csv('./Productos.csv', sep=';', index = False)
